# %% [markdown]
# $$
# \newcommand{\mat}[1]{\boldsymbol {#1}}
# \newcommand{\mattr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\matinv}[1]{\boldsymbol {#1}^{-1}}
# \newcommand{\vec}[1]{\boldsymbol {#1}}
# \newcommand{\vectr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\rvar}[1]{\mathrm {#1}}
# \newcommand{\rvec}[1]{\boldsymbol{\mathrm{#1}}}
# \newcommand{\diag}{\mathop{\mathrm {diag}}}
# \newcommand{\set}[1]{\mathbb {#1}}
# \newcommand{\norm}[1]{\left\lVert#1\right\rVert}
# \newcommand{\pderiv}[2]{\frac{\partial #1}{\partial #2}}
# \newcommand{\bm}[1]{{\bf #1}}
# \newcommand{\bb}[1]{\bm{\mathrm{#1}}}
# $$
#
# # Part 2: Variational Autoencoder
# <a id=part2></a>

# %% [markdown]
# In this part we will learn to generate new data using a special type of autoencoder model which allows us to
# sample from it's latent space. We'll implement and train a VAE and use it to generate new images.

# %%
import unittest
import os
import sys
import pathlib
import urllib
import shutil
import re
import zipfile

import numpy as np
import torch
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

test = unittest.TestCase()
plt.rcParams.update({'font.size': 12})
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %% [markdown]
# ### Obtaining the dataset
# <a id=part2_1></a>

# %% [markdown]
# Let's begin by downloading a dataset of images that we want to learn to generate.
# We'll use the [Labeled Faces in the Wild](http://vis-www.cs.umass.edu/lfw/) (LFW) dataset which contains many labels faces of famous individuals.
#
# We're going to train our generative model to generate a specific face, not just any face.
# Since the person with the most images in this dataset is former president George W. Bush, we'll set out to train a Bush Generator :)
#
# However, if you feel adventurous and/or prefer to generate something else, feel free to edit the `PART2_CUSTOM_DATA_URL` variable in `hw3/answers.py`.

# %%
import cs236605.plot as plot
import cs236605.download
from hw3.answers import PART2_CUSTOM_DATA_URL as CUSTOM_DATA_URL

DATA_DIR = pathlib.Path.home().joinpath('.pytorch-datasets')
if CUSTOM_DATA_URL is None:
    DATA_URL = 'http://vis-www.cs.umass.edu/lfw/lfw-bush.zip'
else:
    DATA_URL = CUSTOM_DATA_URL

_, dataset_dir = cs236605.download.download_data(out_path=DATA_DIR, url=DATA_URL, extract=True, force=False)
# Out:
# File /home/me.halpern/.pytorch-datasets/lfw-bush.zip exists, skipping download.
# Extracting /home/me.halpern/.pytorch-datasets/lfw-bush.zip...
# Extracted 531 to /home/me.halpern/.pytorch-datasets/lfw/George_W_Bush

# %% [markdown]
# Create a `Dataset` object that will load the extraced images:

# %%
import torchvision.transforms as T
from torchvision.datasets import ImageFolder

im_size = 64
tf = T.Compose([
    # Resize to constant spatial dimensions
    T.Resize((im_size, im_size)),
    # PIL.Image -> torch.Tensor
    T.ToTensor(),
    # Dynamic range [0,1] -> [-1, 1]
    T.Normalize(mean=(.5,.5,.5), std=(.5,.5,.5)),
])

ds_gwb = ImageFolder(os.path.dirname(dataset_dir), tf)

# %% [markdown]
# OK, let's see what we got. You can run the following block multiple times to display a random subset of images from the dataset.

# %%
_ = plot.dataset_first_n(ds_gwb, 50, figsize=(10,5), nrows=5)
print(f'Found {len(ds_gwb)} images in dataset folder.')
# Out:
# Found 530 images in dataset folder.

# %%
x0, y0 = ds_gwb[0]
x0 = x0.unsqueeze(0).to(device)
print(x0.shape)

test.assertSequenceEqual(x0.shape, (1, 3, im_size, im_size))
# Out:
# torch.Size([1, 3, 64, 64])

# %% [markdown]
# ## The Variational Autoencoder
# <a id=part2_2></a>

# %% [markdown]
# An autoencoder is a model which learns a representation of data in an **unsupervised** fashion (i.e without any labels).
# Recall it's general form from the lecture:
#
# <img src="imgs/autoencoder.jpg"/>

# %% [markdown]
# An autoencoder maps an instance $\bb{x}$ to a **latent-space** representation $\bb{z}$.
# It has an encoder part, $\Phi_{\bb{\alpha}}(\bb{x})$ (a neural net with parameters $\bb{\alpha}$)
# and a decoder part, $\Psi_{\bb{\beta}}(\bb{z})$ (a neural net with parameters $\bb{\beta}$).
#
# While autoencoders can learn useful representations,
# generally it's hard to use them as generative models because there's no distribution we can sample from in the latent space. In other words, we have no way to choose a point $\bb{z}$ in the latent space
# such that $\Psi(\bb{z})$ will end up on the data manifold in the instance space.
#
# <img src="imgs/ae_sampling.jpg"/>

# %% [markdown]
# The variational autoencoder (VAE), first proposed by [Kingma and Welling](https://arxiv.org/pdf/1312.6114.pdf), addresses this issue by taking a probabilistic perspective.
# Briefly, a VAE model can be described as follows.
#
# We define, in Baysean terminology,
# - The **prior** distribution $p(\bb{Z})$ on points in the latent space.
# - The **likelihood** distribution of a sample $\bb{X}$ given a latent-space representation: $p(\bb{X}|\bb{Z})$.
# - The **posterior** distribution of points in the latent spaces given a specific instance: $p(\bb{Z}|\bb{X})$.
# - The **evidence** distribution $p(\bb{X})$ which is the distribution of the instance space due to the generative process.

# %% [markdown]
# To create our variational **decoder** we'll further specify:
#
# - A parametric likelihood distribution, $p _{\bb{\beta}}(\bb{X} | \bb{z}) = \mathcal{N}( \Psi _{\bb{\beta}}(\bb{z}) , \sigma^2 \bb{I} )$. The interpretation is that given a latent $\bb{z}$, we map it to a point normally distributed around the point calculated by our decoder neural network. Note that here $\sigma^2$ is a hyperparameter while $\vec{\beta}$ represents the network parameters.
# - A fixed latent-space prior distribution of $p(\bb{Z}) = \mathcal{N}(\bb{0},\bb{I})$.
#
# This setting allows us to generate a new instance $\bb{x}$ by sampling $\bb{z}$ from the multivariate normal
# distribution, obtaining the instance-space mean $\Psi _{\bb{\beta}}(\bb{z})$ using our decoder network,
# and then sampling $\bb{x}$ from $\mathcal{N}( \Psi _{\bb{\beta}}(\bb{z}) , \sigma^2 \bb{I} )$.

# %% [markdown]
# Our variational **encoder** will approximate the posterior with a parametric distribution
# $q _{\bb{\alpha}}(\bb{Z} | \bb{x}) \sim
# \mathcal{N}( \bb{\mu} _{\bb{\alpha}}(\bb{x}),  \mathrm{diag}\{ \bb{\sigma}^2_{\bb{\alpha}}(\bb{x}) \} )$.
# The interpretation is that our encoder neural network, $\Phi_{\vec{\alpha}}(\bb{x})$, calculates
# the mean and variance of the posterior distribution, and samples $\bb{z}$ based on them.
# An important nuance here is that our network can't contain any stochastic elements that
# depend on the model parameters, otherwise we won't be able to back-propagate to those parameters.
# So sampling $\bb{z}$ from $\mathcal{N}( \bb{\mu} _{\bb{\alpha}}(\bb{x}),  \mathrm{diag}\{ \bb{\sigma}^2_{\bb{\alpha}}(\bb{x}) \} )$ is not an option.
# The solution is to use what's known as the **reparametrization trick**: sample from an isotropic Gaussian,
# i.e. $\bb{u}\sim\mathcal{N}(\bb{0},\bb{I})$ (which doesn't depend on trainable parameters), and calculate the latent representation as
# $\bb{z} = \bb{\mu} _{\bb{\alpha}}(\bb{x}) + \bb{u}\odot\bb{\sigma}^2_{\bb{\alpha}}(\bb{x})$.

# %% [markdown]
# To train a VAE model, we would like to maximize the evidence, $p(\bb{X})$, because
# $
# p(\bb{X}) = \int p(\bb{X}|{\bb{z}})p(\bb{z})d\bb{z}
# $
# thus maximizing the likelihood of generated instances from over the entire latent space.
#
# The **VAE loss** can therefore be stated as minimizing $\mathcal{L} = -\mathbb{E}_{\bb{x}} \log p(\bb{X})$.
# As we saw in the lecture, this expectation is intractable,
# but we can obtain a lower-bound for $p(\bb{X})$ (the evidence lower bound, "ELBO"):
#
# $$
# \log p(\bb{X}) \ge \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }( \log  p _{\bb{\beta}}(\bb{X} | \bb{z}) )
# -  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{X})\,\left\|\, p(\bb{Z} )\right.\right)
# $$
#
# where
# $
# \mathcal{D} _{\mathrm{KL}}(q\left\|\right.p) =
# \mathbb{E}_{\bb{z}\sim q}\left[ \log \frac{q(\bb{Z})}{p(\bb{Z})} \right]
# $
# is the Kullback-Liebler divergence, which can be interpreted as the information gained by using the posterior $q(\bb{Z|X})$ instead of the prior distribution $p(\bb{Z})$.
#
# Using the ELBO, the VAE loss becomes,
# $$
# \mathcal{L}(\vec{\alpha},\vec{\beta}) = \mathbb{E} _{\bb{x}}  \left[
# \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }\left[ -\log  p _{\bb{\beta}}(\bb{x} | \bb{z}) \right]
# +  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{x})\,\left\|\, p(\bb{Z} )\right.\right)
# \right].
# $$
#
# By remembering that the likelihood is a Gaussian distribution with a diagonal covariance and by applying the reparametrization trick, we can write the above as
#
# $$
# \mathcal{L}(\vec{\alpha},\vec{\beta}) = \mathbb{E} _{\bb{x}}  \left[
# \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }
# \left[
# \frac{1}{2\sigma^2}\left\| \bb{x}- \Psi _{\bb{\beta}}\left(  \bb{\mu} _{\bb{\alpha}}(\bb{x})  + \bb{\Sigma}^{\frac{1}{2}} _{\bb{\alpha}}(\bb{x}) \bb{u}   \right) \right\| _2^2
# \right]
# +  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{x})\,\left\|\, p(\bb{Z} )\right.\right)
# \right].
# $$

# %% [markdown]
# ### Model Implementation
# <a id=part2_3></a>

# %% [markdown]
# Obviously our model will have two parts, an encoder and a decoder.
# Since we're working with images, we'll implement both as deep **convolutional** networks, where the decoder is a "mirror image" of the encoder implemented with adjoint (AKA transposed) convolutions.
# Between the encoder CNN and the decoder CNN we'll implement the sampling from
# the parametric posterior approximator $q_{\bb{\alpha}}(\bb{Z}|\bb{x})$
# to make it a VAE model and not just a regular autoencoder (of course, this is not yet enough to create a VAE,
# since we also need a special loss function which we'll get to later).

# %% [markdown]
# First let's implement just the CNN part of the Encoder network
# (this is not the full $\Phi_{\vec{\alpha}}(\bb{x})$ yet).
# As usual, it should take an input image and map to a activation volume of a specified depth.
# We'll consider this volume as the features we extract from the input image.
# Later we'll use these to create the latent space representation of the input.
# which will be our latent space representation.

# %% [markdown]
# **TODO**: Implement the `EncoderCNN` class in the `hw3/autoencoder.py` module.
# Implement any CNN architecture you like. If you need "architecture inspiration" you can see e.g. [this](https://arxiv.org/pdf/1512.09300.pdf) or [this](https://arxiv.org/pdf/1511.06434.pdf) paper.

# %%
import hw3.autoencoder as autoencoder

in_channels = 3
out_channels = 1024
encoder_cnn = autoencoder.EncoderCNN(in_channels, out_channels).to(device)
print(encoder_cnn)

h = encoder_cnn(x0)
print(h.shape)

test.assertEqual(h.dim(), 4)
test.assertSequenceEqual(h.shape[0:2], (1, out_channels))
# Out:
# EncoderCNN(
#   (cnn): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#     (3): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Conv2d(128, 1024, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): LeakyReLU(negative_slope=0.01)
#   )
# )
# torch.Size([1, 1024, 8, 8])

# %% [markdown]
# Now let's implement the CNN part of the Decoder.
# Again this is not yet the full $\Psi _{\bb{\beta}}(\bb{z})$. It should take an activation volume produced
# by your `EncoderCNN` and output an image of the same dimensions as the Encoder's input was.
# This should be a CNN which is a "mirror image" of the the Encoder. For example, replace convolutions with transposed convolutions, downsampling with up-sampling etc.
# Consult the documentation of [ConvTranspose2D](https://pytorch.org/docs/0.4.1/nn.html#convtranspose2d)
# to figure out how to reverse your convolutional layers in terms of input and output dimensions.

# %% [markdown]
# **TODO**: Implement the `DecoderCNN` class in the `hw3/autoencoder.py` module.

# %%
decoder_cnn = autoencoder.DecoderCNN(in_channels=out_channels, out_channels=in_channels).to(device)
print(decoder_cnn)
x0r = decoder_cnn(h)
print(x0r.shape)

test.assertEqual(x0.shape, x0r.shape)

# Should look like colored noise
T.functional.to_pil_image(x0r[0].cpu().detach())
# Out:
# DecoderCNN(
#   (cnn): Sequential(
#     (0): LeakyReLU(negative_slope=0.01)
#     (1): InstanceNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (2): ConvTranspose2d(1024, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (5): ConvTranspose2d(256, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#     (6): LeakyReLU(negative_slope=0.01)
#     (7): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (8): ConvTranspose2d(128, 32, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#     (9): ConvTranspose2d(32, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   )
# )
# torch.Size([1, 3, 64, 64])
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F7B402D0B38>

# %% [markdown]
# Let's now implement the full VAE Encoder, $\Phi_{\vec{\alpha}}(\vec{x})$.
# It will work as follows:
# 1. Produce a feature vector $\vec{h}$ from the input image $\vec{x}$.
# 2. Use two affine transforms to convert the features into the mean and log-variance of the posterior, i.e.
#     $$
#     \begin{align}
#         \bb{\mu} _{\bb{\alpha}}(\bb{x}) &= \vec{h}\mattr{W}_{\mathrm{h\mu}} + \vec{b}_{\mathrm{h\mu}} \\
#         \log\left(\bb{\sigma}^2_{\bb{\alpha}}(\bb{x})\right) &= \vec{h}\mattr{W}_{\mathrm{h\sigma^2}} + \vec{b}_{\mathrm{h\sigma^2}}
#     \end{align}
#     $$
# 3. Use the **reparametrization trick** to create the latent representation $\vec{z}$.
#
# Note that we model the **log** of the variance, not the actual variance.
# The reason is that the log is easier to optimize, since (a) It doesn't have to be positive, and (b) it has a much larger dynamic range.
# The above formulation is proposed in appendix C of the [VAE paper](https://arxiv.org/pdf/1312.6114.pdf).

# %% [markdown]
# **TODO**: Implement the `encode()` method in the `VAE` class within the `hw3/autoencoder.py` module.
# You'll also need to define your parameters in `__init__()`.

# %%
z_dim = 2
vae = autoencoder.VAE(encoder_cnn, decoder_cnn, x0[0].size(), z_dim).to(device)
print(vae)

z, mu, log_sigma2 = vae.encode(x0)

test.assertSequenceEqual(z.shape, (1, z_dim))
test.assertTrue(z.shape == mu.shape == log_sigma2.shape)

print(f'mu(x0)={list(*mu.detach().cpu().numpy())}, sigma2(x0)={list(*torch.exp(log_sigma2).detach().cpu().numpy())}')

# Sample from q(Z|x)
N = 500
Z = torch.zeros(N, z_dim)
_, ax = plt.subplots()
with torch.no_grad():
    for i in range(500):
        Z[i], _, _ = vae.encode(x0)
        ax.scatter(*Z[i].cpu().numpy())

# Should be close to the above
print('sampled mu', torch.mean(Z, dim=0))
print('sampled sigma2', torch.var(Z, dim=0))
# Out:
# VAE(
#   (features_encoder): EncoderCNN(
#     (cnn): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): LeakyReLU(negative_slope=0.01)
#       (6): Conv2d(128, 1024, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (7): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (features_decoder): DecoderCNN(
#     (cnn): Sequential(
#       (0): LeakyReLU(negative_slope=0.01)
#       (1): InstanceNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (2): ConvTranspose2d(1024, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (5): ConvTranspose2d(256, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#       (6): LeakyReLU(negative_slope=0.01)
#       (7): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (8): ConvTranspose2d(128, 32, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#       (9): ConvTranspose2d(32, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#   )
#   (Utransformation): Linear(in_features=65536, out_features=2, bias=True)
#   (Stransformation): Linear(in_features=65536, out_features=2, bias=True)
#   (Dectransformation): Linear(in_features=2, out_features=65536, bias=True)
# )
# mu(x0)=[0.07305952, -0.3357061], sigma2(x0)=[0.7620326, 1.4980507]
# sampled mu tensor([ 0.0571, -0.2517])
# sampled sigma2 tensor([0.7776, 1.4649])

# %% [markdown]
# Let's now implement the full VAE Decoder, $\Psi _{\bb{\beta}}(\bb{z})$.
# It will work as follows:
# 1. Produce a feature vector $\tilde{\vec{h}}$ from the latent vector $\vec{z}$ using an affine transform.
# 2. Reconstruct an image $\tilde{\vec{x}}$ from $\tilde{\vec{h}}$.

# %% [markdown]
# **TODO**: Implement the `decode()` method in the `VAE` class within the `hw3/autoencoder.py` module.
# You'll also need to define your parameters in `__init__()`. You may need to also re-run the block above after you implement this.

# %%
x0r = vae.decode(z)

test.assertSequenceEqual(x0r.shape, x0.shape)

# %% [markdown]
# Our model's `forward()` function will simply return `decode(encode(x))` as well as the calculated mean and log-variance of the posterior.

# %%
x0r, mu, log_sigma2 = vae(x0)

test.assertSequenceEqual(x0r.shape, x0.shape)
test.assertSequenceEqual(mu.shape, (1, z_dim))
test.assertSequenceEqual(log_sigma2.shape, (1, z_dim))
T.functional.to_pil_image(x0r[0].detach().cpu())
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F7B29603198>

# %% [markdown]
# ### Loss Implementation
# <a id=part2_4></a>

# %% [markdown]
# In practice, since we're using SGD, we'll drop the expectation over $\bb{X}$ and instead sample an instance from the training set and compute a point-wise loss. Similarly, we'll drop the expectation over $\bb{Z}$ by sampling from $q_{\vec{\alpha}}(\bb{Z}|\bb{x})$.
# Additionally, because the KL divergence is between two Gaussian distributions, there is a closed-form expression for it. These points bring us to the following point-wise loss:
#
# $$
# \ell(\vec{\alpha},\vec{\beta};\bb{x}) =
# \frac{1}{\sigma^2} \left\| \bb{x}- \Psi _{\bb{\beta}}\left(  \bb{\mu} _{\bb{\alpha}}(\bb{x})  +
# \bb{\Sigma}^{\frac{1}{2}} _{\bb{\alpha}}(\bb{x}) \bb{u}   \right) \right\| _2^2 +
# \mathrm{tr}\,\bb{\Sigma} _{\bb{\alpha}}(\bb{x}) +  \|\bb{\mu} _{\bb{\alpha}}(\bb{x})\|^2 _2 - d_z - \log\det \bb{\Sigma} _{\bb{\alpha}}(\bb{x})
# $$
#
# where $d_z$ is the dimension of the latent space. This pointwise loss is the quantity that we'll compute and minimize with gradient descent.

# %% [markdown]
# **TODO**: Implement the `vae_loss()` function in the `hw3/autoencoder.py` module.

# %%
from hw3.autoencoder import vae_loss
torch.manual_seed(42)

def test_vae_loss():
    # Test data
    N, C, H, W = 10, 3, 64, 64 
    z_dim = 32
    x  = torch.randn(N, C, H, W)*2 - 1
    xr = torch.randn(N, C, H, W)*2 - 1
    z_mu = torch.randn(N, z_dim)
    z_log_sigma2 = torch.randn(N, z_dim)
    x_sigma2 = 0.9
    
    loss, _, _ = vae_loss(x, xr, z_mu, z_log_sigma2, x_sigma2)
    
    test.assertAlmostEqual(loss.item(), 10.5053434, delta=1e-5)
    return loss

test_vae_loss()
# Out:
# tensor(10.5053)

# %% [markdown]
# ### Sampling
# <a id=part2_5></a>

# %% [markdown]
# The main advantage of a VAE is that it can by used as a generative model by sampling the latent space, since
# we optimize for a Normal prior $p(\bb{Z})$ in the loss function. Let's now implement this so that we can visualize how our model is doing when we train.

# %% [markdown]
# **TODO**: Implement the `sample()` method in the `VAE` class within the `hw3/autoencoder.py` module.

# %%
samples = vae.sample(5)
_ = plot.tensors_as_images(samples)

# %% [markdown]
# ### Training
# <a id=part2_6></a>

# %% [markdown]
# Time to train!

# %% [markdown]
# **TODO**:
# 1. Implement the `VAETrainer` class in the `hw3/training.py` module.
# 2. Tweak the hyperparameters in the `part2_vae_hyperparam()` function within the `hw3/answers.py` module.

# %%
import torch.optim as optim
from torch.utils.data import random_split
from torch.utils.data import DataLoader
from torch.nn import DataParallel
from hw3.training import VAETrainer
from hw3.answers import part2_vae_hyperparams

torch.manual_seed(42)

# Hyperparams
hp = part2_vae_hyperparams()
batch_size = hp['batch_size']
h_dim = hp['h_dim']
z_dim = hp['z_dim']
x_sigma2 = hp['x_sigma2']
learn_rate = hp['learn_rate']
betas = hp['betas']

# Data
split_lengths = [int(len(ds_gwb)*0.9), int(len(ds_gwb)*0.1)]
ds_train, ds_test = random_split(ds_gwb, split_lengths)
dl_train = DataLoader(ds_train, batch_size, shuffle=True)
dl_test  = DataLoader(ds_test,  batch_size, shuffle=True)
im_size = ds_train[0][0].shape

# Model
encoder = autoencoder.EncoderCNN(in_channels=im_size[0], out_channels=h_dim)
decoder = autoencoder.DecoderCNN(in_channels=h_dim, out_channels=im_size[0])
vae = autoencoder.VAE(encoder, decoder, im_size, z_dim)
vae_dp = DataParallel(vae).to(device)

# Optimizer
optimizer = optim.Adam(vae.parameters(), lr=learn_rate, betas=betas)

# Loss
def loss_fn(x, xr, z_mu, z_log_sigma2):
    return autoencoder.vae_loss(x, xr, z_mu, z_log_sigma2, x_sigma2)

# Trainer
trainer = VAETrainer(vae_dp, loss_fn, optimizer, device)
checkpoint_file = 'checkpoints/vae'
checkpoint_file_final = f'{checkpoint_file}_final'
if os.path.isfile(f'{checkpoint_file}.pt'):
    os.remove(f'{checkpoint_file}.pt')

# Show model and hypers
print(vae)
print(hp)
# Out:
# VAE(
#   (features_encoder): EncoderCNN(
#     (cnn): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#       (3): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): LeakyReLU(negative_slope=0.01)
#       (6): Conv2d(128, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (features_decoder): DecoderCNN(
#     (cnn): Sequential(
#       (0): LeakyReLU(negative_slope=0.01)
#       (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (2): ConvTranspose2d(256, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (5): ConvTranspose2d(256, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#       (6): LeakyReLU(negative_slope=0.01)
#       (7): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (8): ConvTranspose2d(128, 32, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#       (9): ConvTranspose2d(32, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#   )
#   (Utransformation): Linear(in_features=16384, out_features=64, bias=True)
#   (Stransformation): Linear(in_features=16384, out_features=64, bias=True)
#   (Dectransformation): Linear(in_features=64, out_features=16384, bias=True)
# )
# {'batch_size': 32, 'h_dim': 256, 'z_dim': 64, 'x_sigma2': 0.8, 'learn_rate': 0.0005, 'betas': (0.5, 0.5)}

# %%
import IPython.display

def post_epoch_fn(epoch, train_result, test_result, verbose):
    # Plot some samples if this is a verbose epoch
    if verbose:
        samples = vae.sample(n=5)
        fig, _ = plot.tensors_as_images(samples, figsize=(6,2))
        IPython.display.display(fig)
        plt.close(fig)

if os.path.isfile(f'{checkpoint_file_final}.pt'):
    print(f'*** Loading final checkpoint file {checkpoint_file_final} instead of training')
    checkpoint_file = checkpoint_file_final
else:
    res = trainer.fit(dl_train, dl_test,
                      num_epochs=200, early_stopping=20, print_every=10,
                      checkpoints=checkpoint_file,
                      post_epoch_fn=post_epoch_fn)
    
# Plot images from best model
saved_state = torch.load(f'{checkpoint_file}.pt', map_location=device)
vae_dp.load_state_dict(saved_state['model_state'])
print('*** Images Generated from best model:')
fig, _ = plot.tensors_as_images(vae_dp.module.sample(n=15), nrows=3, figsize=(6,6))
# Out:
# --- EPOCH 1/200 ---
# train_batch (Avg. Loss 0.784, Accuracy 9.4): 100%|██████████| 15/15 [00:03<00:00,  4.39it/s]
# test_batch (Avg. Loss 0.418, Accuracy 12.5): 100%|██████████| 2/2 [00:00<00:00,  5.23it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 1
# train_batch (Avg. Loss 0.480, Accuracy 10.3): 100%|██████████| 15/15 [00:03<00:00,  4.36it/s]
# test_batch (Avg. Loss 0.408, Accuracy 13.3): 100%|██████████| 2/2 [00:00<00:00,  5.43it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 2
# train_batch (Avg. Loss 0.434, Accuracy 11.0): 100%|██████████| 15/15 [00:03<00:00,  4.29it/s]
# test_batch (Avg. Loss 0.389, Accuracy 13.7): 100%|██████████| 2/2 [00:00<00:00,  5.31it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 3
# train_batch (Avg. Loss 0.418, Accuracy 11.1): 100%|██████████| 15/15 [00:03<00:00,  4.36it/s]
# test_batch (Avg. Loss 0.413, Accuracy 14.0): 100%|██████████| 2/2 [00:00<00:00,  5.39it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 4
# train_batch (Avg. Loss 0.394, Accuracy 11.5): 100%|██████████| 15/15 [00:03<00:00,  4.33it/s]
# test_batch (Avg. Loss 0.369, Accuracy 14.3): 100%|██████████| 2/2 [00:00<00:00,  5.37it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 5
# train_batch (Avg. Loss 0.386, Accuracy 11.7): 100%|██████████| 15/15 [00:03<00:00,  4.33it/s]
# test_batch (Avg. Loss 0.390, Accuracy 13.4): 100%|██████████| 2/2 [00:00<00:00,  5.18it/s]
# train_batch (Avg. Loss 0.381, Accuracy 11.8): 100%|██████████| 15/15 [00:03<00:00,  4.40it/s]
# test_batch (Avg. Loss 0.358, Accuracy 14.4): 100%|██████████| 2/2 [00:00<00:00,  5.36it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 7
# train_batch (Avg. Loss 0.353, Accuracy 12.0): 100%|██████████| 15/15 [00:03<00:00,  4.26it/s]
# test_batch (Avg. Loss 0.352, Accuracy 14.7): 100%|██████████| 2/2 [00:00<00:00,  5.23it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 8
# train_batch (Avg. Loss 0.359, Accuracy 12.1): 100%|██████████| 15/15 [00:03<00:00,  4.36it/s]
# test_batch (Avg. Loss 0.369, Accuracy 13.8): 100%|██████████| 2/2 [00:00<00:00,  5.33it/s]
# train_batch (Avg. Loss 0.350, Accuracy 12.0): 100%|██████████| 15/15 [00:03<00:00,  4.33it/s]
# test_batch (Avg. Loss 0.335, Accuracy 14.6): 100%|██████████| 2/2 [00:00<00:00,  5.22it/s]
# --- EPOCH 11/200 ---
# train_batch (Avg. Loss 0.348, Accuracy 12.2): 100%|██████████| 15/15 [00:03<00:00,  4.36it/s]
# test_batch (Avg. Loss 0.328, Accuracy 15.1): 100%|██████████| 2/2 [00:00<00:00,  5.32it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 11
# train_batch (Avg. Loss 0.356, Accuracy 11.9): 100%|██████████| 15/15 [00:03<00:00,  5.19it/s]
# test_batch (Avg. Loss 0.336, Accuracy 14.5): 100%|██████████| 2/2 [00:00<00:00,  6.48it/s]
# train_batch (Avg. Loss 0.340, Accuracy 12.2): 100%|██████████| 15/15 [00:03<00:00,  4.17it/s]
# test_batch (Avg. Loss 0.341, Accuracy 14.3): 100%|██████████| 2/2 [00:00<00:00,  5.15it/s]
# train_batch (Avg. Loss 0.345, Accuracy 12.2): 100%|██████████| 15/15 [00:03<00:00,  4.41it/s]
# test_batch (Avg. Loss 0.337, Accuracy 14.4): 100%|██████████| 2/2 [00:00<00:00,  5.31it/s]
# train_batch (Avg. Loss 0.334, Accuracy 12.4): 100%|██████████| 15/15 [00:03<00:00,  4.29it/s]
# test_batch (Avg. Loss 0.335, Accuracy 14.7): 100%|██████████| 2/2 [00:00<00:00,  5.29it/s]
# train_batch (Avg. Loss 0.337, Accuracy 12.3): 100%|██████████| 15/15 [00:03<00:00,  4.33it/s]
# test_batch (Avg. Loss 0.348, Accuracy 14.0): 100%|██████████| 2/2 [00:00<00:00,  5.34it/s]
# train_batch (Avg. Loss 0.333, Accuracy 12.4): 100%|██████████| 15/15 [00:03<00:00,  4.30it/s]
# test_batch (Avg. Loss 0.331, Accuracy 14.7): 100%|██████████| 2/2 [00:00<00:00,  5.43it/s]
# train_batch (Avg. Loss 0.335, Accuracy 12.2): 100%|██████████| 15/15 [00:03<00:00,  3.62it/s]
# test_batch (Avg. Loss 0.331, Accuracy 14.5): 100%|██████████| 2/2 [00:00<00:00,  5.27it/s]
# train_batch (Avg. Loss 0.323, Accuracy 12.6): 100%|██████████| 15/15 [00:03<00:00,  4.36it/s]
# test_batch (Avg. Loss 0.333, Accuracy 14.6): 100%|██████████| 2/2 [00:00<00:00,  5.28it/s]
# train_batch (Avg. Loss 0.327, Accuracy 12.7): 100%|██████████| 15/15 [00:03<00:00,  4.38it/s]
# test_batch (Avg. Loss 0.333, Accuracy 14.4): 100%|██████████| 2/2 [00:00<00:00,  5.21it/s]
# --- EPOCH 21/200 ---
# train_batch (Avg. Loss 0.328, Accuracy 12.3): 100%|██████████| 15/15 [00:03<00:00,  4.45it/s]
# test_batch (Avg. Loss 0.325, Accuracy 15.0): 100%|██████████| 2/2 [00:00<00:00,  5.32it/s]
# train_batch (Avg. Loss 0.321, Accuracy 12.8): 100%|██████████| 15/15 [00:03<00:00,  4.44it/s]
# test_batch (Avg. Loss 0.331, Accuracy 14.8): 100%|██████████| 2/2 [00:00<00:00,  5.29it/s]
# train_batch (Avg. Loss 0.331, Accuracy 12.5): 100%|██████████| 15/15 [00:03<00:00,  4.40it/s]
# test_batch (Avg. Loss 0.327, Accuracy 14.9): 100%|██████████| 2/2 [00:00<00:00,  5.35it/s]
# train_batch (Avg. Loss 0.324, Accuracy 12.8): 100%|██████████| 15/15 [00:03<00:00,  4.39it/s]
# test_batch (Avg. Loss 0.314, Accuracy 15.6): 100%|██████████| 2/2 [00:00<00:00,  5.44it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 24
# train_batch (Avg. Loss 0.318, Accuracy 13.2): 100%|██████████| 15/15 [00:03<00:00,  4.35it/s]
# test_batch (Avg. Loss 0.336, Accuracy 14.9): 100%|██████████| 2/2 [00:00<00:00,  5.32it/s]
# train_batch (Avg. Loss 0.314, Accuracy 13.4): 100%|██████████| 15/15 [00:03<00:00,  4.28it/s]
# test_batch (Avg. Loss 0.312, Accuracy 15.7): 100%|██████████| 2/2 [00:00<00:00,  5.40it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 26
# train_batch (Avg. Loss 0.315, Accuracy 13.4): 100%|██████████| 15/15 [00:03<00:00,  4.23it/s]
# test_batch (Avg. Loss 0.322, Accuracy 15.5): 100%|██████████| 2/2 [00:00<00:00,  5.10it/s]
# train_batch (Avg. Loss 0.328, Accuracy 13.1): 100%|██████████| 15/15 [00:03<00:00,  4.42it/s]
# test_batch (Avg. Loss 0.338, Accuracy 14.6): 100%|██████████| 2/2 [00:00<00:00,  5.30it/s]
# train_batch (Avg. Loss 0.317, Accuracy 13.2): 100%|██████████| 15/15 [00:03<00:00,  4.37it/s]
# test_batch (Avg. Loss 0.322, Accuracy 15.1): 100%|██████████| 2/2 [00:00<00:00,  5.36it/s]
# train_batch (Avg. Loss 0.307, Accuracy 13.7): 100%|██████████| 15/15 [00:03<00:00,  5.29it/s]
# test_batch (Avg. Loss 0.354, Accuracy 14.4): 100%|██████████| 2/2 [00:00<00:00,  6.80it/s]
# --- EPOCH 31/200 ---
# train_batch (Avg. Loss 0.320, Accuracy 13.1): 100%|██████████| 15/15 [00:02<00:00,  5.29it/s]
# test_batch (Avg. Loss 0.335, Accuracy 14.9): 100%|██████████| 2/2 [00:00<00:00,  3.12it/s]
# train_batch (Avg. Loss 0.308, Accuracy 13.6): 100%|██████████| 15/15 [00:02<00:00,  5.32it/s]
# test_batch (Avg. Loss 0.322, Accuracy 15.4): 100%|██████████| 2/2 [00:00<00:00,  6.71it/s]
# train_batch (Avg. Loss 0.307, Accuracy 13.7): 100%|██████████| 15/15 [00:02<00:00,  5.28it/s]
# test_batch (Avg. Loss 0.300, Accuracy 16.6): 100%|██████████| 2/2 [00:00<00:00,  6.56it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 33
# train_batch (Avg. Loss 0.302, Accuracy 13.9): 100%|██████████| 15/15 [00:02<00:00,  5.30it/s]
# test_batch (Avg. Loss 0.304, Accuracy 16.2): 100%|██████████| 2/2 [00:00<00:00,  6.75it/s]
# train_batch (Avg. Loss 0.316, Accuracy 13.5): 100%|██████████| 15/15 [00:02<00:00,  5.34it/s]
# test_batch (Avg. Loss 0.295, Accuracy 17.0): 100%|██████████| 2/2 [00:00<00:00,  6.78it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 35
# train_batch (Avg. Loss 0.320, Accuracy 13.3): 100%|██████████| 15/15 [00:02<00:00,  5.27it/s]
# test_batch (Avg. Loss 0.313, Accuracy 15.9): 100%|██████████| 2/2 [00:00<00:00,  6.63it/s]
# train_batch (Avg. Loss 0.311, Accuracy 13.7): 100%|██████████| 15/15 [00:02<00:00,  5.36it/s]
# test_batch (Avg. Loss 0.295, Accuracy 16.7): 100%|██████████| 2/2 [00:00<00:00,  6.80it/s]
# train_batch (Avg. Loss 0.299, Accuracy 14.1): 100%|██████████| 15/15 [00:02<00:00,  5.29it/s]
# test_batch (Avg. Loss 0.300, Accuracy 16.6): 100%|██████████| 2/2 [00:00<00:00,  6.80it/s]
# train_batch (Avg. Loss 0.310, Accuracy 13.7): 100%|██████████| 15/15 [00:03<00:00,  5.14it/s]
# test_batch (Avg. Loss 0.325, Accuracy 15.3): 100%|██████████| 2/2 [00:00<00:00,  6.87it/s]
# train_batch (Avg. Loss 0.306, Accuracy 13.9): 100%|██████████| 15/15 [00:03<00:00,  4.39it/s]
# test_batch (Avg. Loss 0.342, Accuracy 14.7): 100%|██████████| 2/2 [00:00<00:00,  5.26it/s]
# --- EPOCH 41/200 ---
# train_batch (Avg. Loss 0.325, Accuracy 13.3): 100%|██████████| 15/15 [00:03<00:00,  4.43it/s]
# test_batch (Avg. Loss 0.319, Accuracy 15.7): 100%|██████████| 2/2 [00:00<00:00,  5.35it/s]
# train_batch (Avg. Loss 0.307, Accuracy 14.0): 100%|██████████| 15/15 [00:03<00:00,  4.49it/s]
# test_batch (Avg. Loss 0.372, Accuracy 13.4): 100%|██████████| 2/2 [00:00<00:00,  6.84it/s]
# train_batch (Avg. Loss 0.308, Accuracy 13.8): 100%|██████████| 15/15 [00:02<00:00,  5.30it/s]
# test_batch (Avg. Loss 0.307, Accuracy 16.3): 100%|██████████| 2/2 [00:00<00:00,  6.76it/s]
# train_batch (Avg. Loss 0.310, Accuracy 13.9): 100%|██████████| 15/15 [00:03<00:00,  4.54it/s]
# test_batch (Avg. Loss 0.302, Accuracy 16.4): 100%|██████████| 2/2 [00:00<00:00,  2.75it/s]
# train_batch (Avg. Loss 0.319, Accuracy 13.4): 100%|██████████| 15/15 [00:03<00:00,  4.32it/s]
# test_batch (Avg. Loss 0.320, Accuracy 15.7): 100%|██████████| 2/2 [00:00<00:00,  5.23it/s]
# train_batch (Avg. Loss 0.304, Accuracy 14.0): 100%|██████████| 15/15 [00:03<00:00,  4.50it/s]
# test_batch (Avg. Loss 0.298, Accuracy 16.8): 100%|██████████| 2/2 [00:00<00:00,  5.31it/s]
# train_batch (Avg. Loss 0.302, Accuracy 14.2): 100%|██████████| 15/15 [00:03<00:00,  4.35it/s]
# test_batch (Avg. Loss 0.302, Accuracy 17.0): 100%|██████████| 2/2 [00:00<00:00,  5.17it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 47
# train_batch (Avg. Loss 0.311, Accuracy 13.9): 100%|██████████| 15/15 [00:03<00:00,  4.33it/s]
# test_batch (Avg. Loss 0.302, Accuracy 16.4): 100%|██████████| 2/2 [00:00<00:00,  5.38it/s]
# train_batch (Avg. Loss 0.308, Accuracy 13.8): 100%|██████████| 15/15 [00:03<00:00,  3.49it/s]
# test_batch (Avg. Loss 0.329, Accuracy 15.7): 100%|██████████| 2/2 [00:00<00:00,  5.23it/s]
# train_batch (Avg. Loss 0.316, Accuracy 13.6): 100%|██████████| 15/15 [00:03<00:00,  4.30it/s]
# test_batch (Avg. Loss 0.294, Accuracy 17.3): 100%|██████████| 2/2 [00:00<00:00,  5.20it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 50
# --- EPOCH 51/200 ---
# train_batch (Avg. Loss 0.294, Accuracy 14.5): 100%|██████████| 15/15 [00:03<00:00,  4.39it/s]
# test_batch (Avg. Loss 0.308, Accuracy 16.8): 100%|██████████| 2/2 [00:00<00:00,  5.15it/s]
# train_batch (Avg. Loss 0.292, Accuracy 14.7): 100%|██████████| 15/15 [00:04<00:00,  3.90it/s]
# test_batch (Avg. Loss 0.333, Accuracy 14.8): 100%|██████████| 2/2 [00:00<00:00,  5.20it/s]
# train_batch (Avg. Loss 0.295, Accuracy 14.4): 100%|██████████| 15/15 [00:03<00:00,  4.26it/s]
# test_batch (Avg. Loss 0.297, Accuracy 17.0): 100%|██████████| 2/2 [00:00<00:00,  5.16it/s]
# train_batch (Avg. Loss 0.294, Accuracy 14.7): 100%|██████████| 15/15 [00:03<00:00,  4.36it/s]
# test_batch (Avg. Loss 0.405, Accuracy 12.2): 100%|██████████| 2/2 [00:00<00:00,  5.27it/s]
# train_batch (Avg. Loss 0.315, Accuracy 13.8): 100%|██████████| 15/15 [00:03<00:00,  4.36it/s]
# test_batch (Avg. Loss 0.336, Accuracy 14.8): 100%|██████████| 2/2 [00:00<00:00,  5.37it/s]
# train_batch (Avg. Loss 0.317, Accuracy 13.5): 100%|██████████| 15/15 [00:03<00:00,  4.29it/s]
# test_batch (Avg. Loss 0.307, Accuracy 16.3): 100%|██████████| 2/2 [00:00<00:00,  5.41it/s]
# train_batch (Avg. Loss 0.307, Accuracy 13.9): 100%|██████████| 15/15 [00:03<00:00,  4.36it/s]
# test_batch (Avg. Loss 0.291, Accuracy 17.2): 100%|██████████| 2/2 [00:00<00:00,  5.33it/s]
# train_batch (Avg. Loss 0.301, Accuracy 14.1): 100%|██████████| 15/15 [00:03<00:00,  4.18it/s]
# test_batch (Avg. Loss 0.321, Accuracy 15.8): 100%|██████████| 2/2 [00:00<00:00,  5.43it/s]
# train_batch (Avg. Loss 0.298, Accuracy 14.3): 100%|██████████| 15/15 [00:03<00:00,  4.34it/s]
# test_batch (Avg. Loss 0.284, Accuracy 17.8): 100%|██████████| 2/2 [00:00<00:00,  5.35it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 59
# train_batch (Avg. Loss 0.316, Accuracy 13.7): 100%|██████████| 15/15 [00:03<00:00,  5.13it/s]
# test_batch (Avg. Loss 0.300, Accuracy 17.0): 100%|██████████| 2/2 [00:00<00:00,  6.73it/s]
# --- EPOCH 61/200 ---
# train_batch (Avg. Loss 0.290, Accuracy 14.8): 100%|██████████| 15/15 [00:02<00:00,  5.30it/s]
# test_batch (Avg. Loss 0.293, Accuracy 17.3): 100%|██████████| 2/2 [00:00<00:00,  6.85it/s]
# train_batch (Avg. Loss 0.309, Accuracy 14.1): 100%|██████████| 15/15 [00:03<00:00,  3.87it/s]
# test_batch (Avg. Loss 0.305, Accuracy 16.7): 100%|██████████| 2/2 [00:00<00:00,  5.53it/s]
# train_batch (Avg. Loss 0.305, Accuracy 14.0): 100%|██████████| 15/15 [00:02<00:00,  5.24it/s]
# test_batch (Avg. Loss 0.326, Accuracy 15.6): 100%|██████████| 2/2 [00:00<00:00,  5.91it/s]
# train_batch (Avg. Loss 0.312, Accuracy 13.8): 100%|██████████| 15/15 [00:02<00:00,  5.36it/s]
# test_batch (Avg. Loss 0.315, Accuracy 16.5): 100%|██████████| 2/2 [00:00<00:00,  6.63it/s]
# train_batch (Avg. Loss 0.301, Accuracy 14.4): 100%|██████████| 15/15 [00:02<00:00,  5.28it/s]
# test_batch (Avg. Loss 0.328, Accuracy 15.6): 100%|██████████| 2/2 [00:00<00:00,  6.63it/s]
# train_batch (Avg. Loss 0.297, Accuracy 14.5): 100%|██████████| 15/15 [00:03<00:00,  4.26it/s]
# test_batch (Avg. Loss 0.304, Accuracy 17.0): 100%|██████████| 2/2 [00:00<00:00,  5.44it/s]
# train_batch (Avg. Loss 0.293, Accuracy 14.8): 100%|██████████| 15/15 [00:03<00:00,  4.29it/s]
# test_batch (Avg. Loss 0.371, Accuracy 13.6): 100%|██████████| 2/2 [00:00<00:00,  5.47it/s]
# train_batch (Avg. Loss 0.305, Accuracy 14.1): 100%|██████████| 15/15 [00:03<00:00,  4.34it/s]
# test_batch (Avg. Loss 0.295, Accuracy 17.3): 100%|██████████| 2/2 [00:00<00:00,  5.42it/s]
# train_batch (Avg. Loss 0.303, Accuracy 14.4): 100%|██████████| 15/15 [00:03<00:00,  4.34it/s]
# test_batch (Avg. Loss 0.354, Accuracy 14.6): 100%|██████████| 2/2 [00:00<00:00,  4.61it/s]
# train_batch (Avg. Loss 0.316, Accuracy 13.7): 100%|██████████| 15/15 [00:03<00:00,  4.34it/s]
# test_batch (Avg. Loss 0.303, Accuracy 16.4): 100%|██████████| 2/2 [00:00<00:00,  5.31it/s]
# --- EPOCH 71/200 ---
# train_batch (Avg. Loss 0.303, Accuracy 14.3): 100%|██████████| 15/15 [00:03<00:00,  4.38it/s]
# test_batch (Avg. Loss 0.342, Accuracy 15.1): 100%|██████████| 2/2 [00:00<00:00,  5.32it/s]
# train_batch (Avg. Loss 0.295, Accuracy 14.5): 100%|██████████| 15/15 [00:03<00:00,  4.38it/s]
# test_batch (Avg. Loss 0.309, Accuracy 16.3): 100%|██████████| 2/2 [00:00<00:00,  5.18it/s]
# train_batch (Avg. Loss 0.306, Accuracy 14.1): 100%|██████████| 15/15 [00:03<00:00,  4.32it/s]
# test_batch (Avg. Loss 0.327, Accuracy 15.6): 100%|██████████| 2/2 [00:00<00:00,  2.75it/s]
# train_batch (Avg. Loss 0.303, Accuracy 14.6): 100%|██████████| 15/15 [00:03<00:00,  4.24it/s]
# test_batch (Avg. Loss 0.320, Accuracy 15.8): 100%|██████████| 2/2 [00:00<00:00,  5.29it/s]
# train_batch (Avg. Loss 0.300, Accuracy 14.3): 100%|██████████| 15/15 [00:03<00:00,  3.30it/s]
# test_batch (Avg. Loss 0.355, Accuracy 15.0): 100%|██████████| 2/2 [00:00<00:00,  5.17it/s]
# train_batch (Avg. Loss 0.304, Accuracy 14.3): 100%|██████████| 15/15 [00:03<00:00,  4.29it/s]
# test_batch (Avg. Loss 0.295, Accuracy 17.2): 100%|██████████| 2/2 [00:00<00:00,  4.92it/s]
# train_batch (Avg. Loss 0.316, Accuracy 13.7): 100%|██████████| 15/15 [00:03<00:00,  4.37it/s]
# test_batch (Avg. Loss 0.284, Accuracy 17.7): 100%|██████████| 2/2 [00:00<00:00,  5.33it/s]
# train_batch (Avg. Loss 0.294, Accuracy 14.5): 100%|██████████| 15/15 [00:03<00:00,  5.08it/s]
# test_batch (Avg. Loss 0.354, Accuracy 14.5): 100%|██████████| 2/2 [00:00<00:00,  6.59it/s]
# train_batch (Avg. Loss 0.315, Accuracy 13.9): 100%|██████████| 15/15 [00:02<00:00,  5.37it/s]
# test_batch (Avg. Loss 0.286, Accuracy 17.5): 100%|██████████| 2/2 [00:00<00:00,  6.85it/s]
# train_batch (Avg. Loss 0.305, Accuracy 14.2): 100%|██████████| 15/15 [00:02<00:00,  5.39it/s]
# test_batch (Avg. Loss 0.331, Accuracy 15.5): 100%|██████████| 2/2 [00:00<00:00,  6.74it/s]
# --- EPOCH 81/200 ---
# train_batch (Avg. Loss 0.319, Accuracy 13.7): 100%|██████████| 15/15 [00:02<00:00,  5.33it/s]
# test_batch (Avg. Loss 0.297, Accuracy 17.3): 100%|██████████| 2/2 [00:00<00:00,  6.75it/s]
# train_batch (Avg. Loss 0.314, Accuracy 13.8): 100%|██████████| 15/15 [00:02<00:00,  5.20it/s]
# test_batch (Avg. Loss 0.330, Accuracy 15.3): 100%|██████████| 2/2 [00:00<00:00,  6.56it/s]
# train_batch (Avg. Loss 0.309, Accuracy 14.0): 100%|██████████| 15/15 [00:03<00:00,  4.17it/s]
# test_batch (Avg. Loss 0.295, Accuracy 17.3): 100%|██████████| 2/2 [00:00<00:00,  5.32it/s]
# train_batch (Avg. Loss 0.302, Accuracy 14.2): 100%|██████████| 15/15 [00:03<00:00,  3.93it/s]
# test_batch (Avg. Loss 0.374, Accuracy 13.5): 100%|██████████| 2/2 [00:00<00:00,  5.22it/s]
# train_batch (Avg. Loss 0.328, Accuracy 13.9): 100%|██████████| 15/15 [00:03<00:00,  4.35it/s]
# test_batch (Avg. Loss 0.335, Accuracy 15.2): 100%|██████████| 2/2 [00:00<00:00,  5.24it/s]
# train_batch (Avg. Loss 0.291, Accuracy 14.9): 100%|██████████| 15/15 [00:03<00:00,  4.29it/s]
# test_batch (Avg. Loss 0.372, Accuracy 14.1): 100%|██████████| 2/2 [00:00<00:00,  5.20it/s]
# train_batch (Avg. Loss 0.309, Accuracy 14.2): 100%|██████████| 15/15 [00:03<00:00,  4.27it/s]
# test_batch (Avg. Loss 0.300, Accuracy 16.8): 100%|██████████| 2/2 [00:00<00:00,  5.36it/s]
# train_batch (Avg. Loss 0.317, Accuracy 13.8): 100%|██████████| 15/15 [00:03<00:00,  4.33it/s]
# test_batch (Avg. Loss 0.305, Accuracy 16.6): 100%|██████████| 2/2 [00:00<00:00,  4.94it/s]
# train_batch (Avg. Loss 0.302, Accuracy 14.3): 100%|██████████| 15/15 [00:03<00:00,  4.29it/s]
# test_batch (Avg. Loss 0.286, Accuracy 17.5): 100%|██████████| 2/2 [00:00<00:00,  4.92it/s]
# train_batch (Avg. Loss 0.299, Accuracy 14.3): 100%|██████████| 15/15 [00:03<00:00,  4.31it/s]
# test_batch (Avg. Loss 0.309, Accuracy 16.7): 100%|██████████| 2/2 [00:00<00:00,  5.02it/s]
# --- EPOCH 91/200 ---
# train_batch (Avg. Loss 0.294, Accuracy 14.7): 100%|██████████| 15/15 [00:03<00:00,  4.24it/s]
# test_batch (Avg. Loss 0.290, Accuracy 17.6): 100%|██████████| 2/2 [00:00<00:00,  5.21it/s]
# train_batch (Avg. Loss 0.287, Accuracy 15.1): 100%|██████████| 15/15 [00:03<00:00,  4.35it/s]
# test_batch (Avg. Loss 0.284, Accuracy 17.8): 100%|██████████| 2/2 [00:00<00:00,  5.29it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 92
# train_batch (Avg. Loss 0.309, Accuracy 13.9): 100%|██████████| 15/15 [00:03<00:00,  4.29it/s]
# test_batch (Avg. Loss 0.302, Accuracy 17.0): 100%|██████████| 2/2 [00:00<00:00,  5.24it/s]
# train_batch (Avg. Loss 0.301, Accuracy 14.4): 100%|██████████| 15/15 [00:03<00:00,  4.30it/s]
# test_batch (Avg. Loss 0.293, Accuracy 17.3): 100%|██████████| 2/2 [00:00<00:00,  5.37it/s]
# train_batch (Avg. Loss 0.305, Accuracy 14.2): 100%|██████████| 15/15 [00:03<00:00,  4.32it/s]
# test_batch (Avg. Loss 0.309, Accuracy 16.5): 100%|██████████| 2/2 [00:00<00:00,  5.27it/s]
# train_batch (Avg. Loss 0.298, Accuracy 14.5): 100%|██████████| 15/15 [00:03<00:00,  4.33it/s]
# test_batch (Avg. Loss 0.316, Accuracy 16.0): 100%|██████████| 2/2 [00:00<00:00,  5.33it/s]
# train_batch (Avg. Loss 0.283, Accuracy 15.1): 100%|██████████| 15/15 [00:03<00:00,  4.35it/s]
# test_batch (Avg. Loss 0.303, Accuracy 16.9): 100%|██████████| 2/2 [00:00<00:00,  5.23it/s]
# train_batch (Avg. Loss 0.323, Accuracy 13.7): 100%|██████████| 15/15 [00:03<00:00,  4.26it/s]
# test_batch (Avg. Loss 0.305, Accuracy 17.1): 100%|██████████| 2/2 [00:00<00:00,  5.48it/s]
# train_batch (Avg. Loss 0.288, Accuracy 14.9): 100%|██████████| 15/15 [00:03<00:00,  4.28it/s]
# test_batch (Avg. Loss 0.290, Accuracy 17.7): 100%|██████████| 2/2 [00:00<00:00,  5.12it/s]
# train_batch (Avg. Loss 0.296, Accuracy 14.5): 100%|██████████| 15/15 [00:03<00:00,  3.49it/s]
# test_batch (Avg. Loss 0.294, Accuracy 17.8): 100%|██████████| 2/2 [00:00<00:00,  5.33it/s]
# --- EPOCH 101/200 ---
# train_batch (Avg. Loss 0.292, Accuracy 14.8): 100%|██████████| 15/15 [00:03<00:00,  4.30it/s]
# test_batch (Avg. Loss 0.277, Accuracy 18.1): 100%|██████████| 2/2 [00:00<00:00,  5.35it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 101
# train_batch (Avg. Loss 0.300, Accuracy 14.5): 100%|██████████| 15/15 [00:03<00:00,  4.23it/s]
# test_batch (Avg. Loss 0.296, Accuracy 17.4): 100%|██████████| 2/2 [00:00<00:00,  5.15it/s]
# train_batch (Avg. Loss 0.306, Accuracy 14.2): 100%|██████████| 15/15 [00:03<00:00,  4.06it/s]
# test_batch (Avg. Loss 0.289, Accuracy 17.8): 100%|██████████| 2/2 [00:00<00:00,  5.37it/s]
# train_batch (Avg. Loss 0.292, Accuracy 14.8): 100%|██████████| 15/15 [00:03<00:00,  3.52it/s]
# test_batch (Avg. Loss 0.303, Accuracy 16.6): 100%|██████████| 2/2 [00:00<00:00,  5.06it/s]
# train_batch (Avg. Loss 0.292, Accuracy 14.9): 100%|██████████| 15/15 [00:03<00:00,  4.25it/s]
# test_batch (Avg. Loss 0.318, Accuracy 16.2): 100%|██████████| 2/2 [00:00<00:00,  5.18it/s]
# train_batch (Avg. Loss 0.290, Accuracy 14.9): 100%|██████████| 15/15 [00:03<00:00,  4.10it/s]
# test_batch (Avg. Loss 0.293, Accuracy 17.1): 100%|██████████| 2/2 [00:00<00:00,  5.05it/s]
# train_batch (Avg. Loss 0.305, Accuracy 14.4): 100%|██████████| 15/15 [00:03<00:00,  4.31it/s]
# test_batch (Avg. Loss 0.325, Accuracy 15.7): 100%|██████████| 2/2 [00:00<00:00,  5.19it/s]
# train_batch (Avg. Loss 0.296, Accuracy 14.5): 100%|██████████| 15/15 [00:03<00:00,  4.34it/s]
# test_batch (Avg. Loss 0.317, Accuracy 16.1): 100%|██████████| 2/2 [00:00<00:00,  5.30it/s]
# train_batch (Avg. Loss 0.291, Accuracy 14.8): 100%|██████████| 15/15 [00:03<00:00,  4.27it/s]
# test_batch (Avg. Loss 0.287, Accuracy 17.8): 100%|██████████| 2/2 [00:00<00:00,  5.28it/s]
# train_batch (Avg. Loss 0.297, Accuracy 14.5): 100%|██████████| 15/15 [00:03<00:00,  3.54it/s]
# test_batch (Avg. Loss 0.292, Accuracy 17.3): 100%|██████████| 2/2 [00:00<00:00,  5.07it/s]
# --- EPOCH 111/200 ---
# train_batch (Avg. Loss 0.311, Accuracy 14.0): 100%|██████████| 15/15 [00:03<00:00,  5.02it/s]
# test_batch (Avg. Loss 0.303, Accuracy 16.8): 100%|██████████| 2/2 [00:00<00:00,  6.70it/s]
# train_batch (Avg. Loss 0.282, Accuracy 15.2): 100%|██████████| 15/15 [00:02<00:00,  4.96it/s]
# test_batch (Avg. Loss 0.305, Accuracy 16.4): 100%|██████████| 2/2 [00:00<00:00,  6.59it/s]
# train_batch (Avg. Loss 0.298, Accuracy 14.5): 100%|██████████| 15/15 [00:02<00:00,  5.26it/s]
# test_batch (Avg. Loss 0.320, Accuracy 16.5): 100%|██████████| 2/2 [00:00<00:00,  6.71it/s]
# train_batch (Avg. Loss 0.294, Accuracy 14.7): 100%|██████████| 15/15 [00:02<00:00,  5.25it/s]
# test_batch (Avg. Loss 0.306, Accuracy 16.5): 100%|██████████| 2/2 [00:00<00:00,  6.80it/s]
# train_batch (Avg. Loss 0.289, Accuracy 14.9): 100%|██████████| 15/15 [00:02<00:00,  5.36it/s]
# test_batch (Avg. Loss 0.304, Accuracy 16.8): 100%|██████████| 2/2 [00:00<00:00,  6.80it/s]
# train_batch (Avg. Loss 0.307, Accuracy 14.2): 100%|██████████| 15/15 [00:03<00:00,  4.43it/s]
# test_batch (Avg. Loss 0.291, Accuracy 17.4): 100%|██████████| 2/2 [00:00<00:00,  5.34it/s]
# train_batch (Avg. Loss 0.289, Accuracy 14.9): 100%|██████████| 15/15 [00:03<00:00,  4.37it/s]
# test_batch (Avg. Loss 0.292, Accuracy 17.5): 100%|██████████| 2/2 [00:00<00:00,  5.22it/s]
# train_batch (Avg. Loss 0.299, Accuracy 14.5): 100%|██████████| 15/15 [00:03<00:00,  4.34it/s]
# test_batch (Avg. Loss 0.287, Accuracy 17.7): 100%|██████████| 2/2 [00:00<00:00,  5.41it/s]
# train_batch (Avg. Loss 0.306, Accuracy 14.2): 100%|██████████| 15/15 [00:03<00:00,  4.39it/s]
# test_batch (Avg. Loss 0.318, Accuracy 16.2): 100%|██████████| 2/2 [00:00<00:00,  5.32it/s]
# train_batch (Avg. Loss 0.300, Accuracy 14.4): 100%|██████████| 15/15 [00:03<00:00,  4.31it/s]
# test_batch (Avg. Loss 0.288, Accuracy 17.5): 100%|██████████| 2/2 [00:00<00:00,  5.26it/s]
# --- EPOCH 121/200 ---
# train_batch (Avg. Loss 0.312, Accuracy 14.1): 100%|██████████| 15/15 [00:03<00:00,  4.34it/s]
# test_batch (Avg. Loss 0.294, Accuracy 17.1): 100%|██████████| 2/2 [00:00<00:00,  5.24it/s]
# train_batch (Avg. Loss 0.304, Accuracy 14.1): 100%|██████████| 15/15 [00:03<00:00,  4.28it/s]
# test_batch (Avg. Loss 0.297, Accuracy 16.9): 100%|██████████| 2/2 [00:00<00:00,  5.31it/s]
# train_batch (Avg. Loss 0.287, Accuracy 15.0): 100%|██████████| 15/15 [00:03<00:00,  4.32it/s]
# test_batch (Avg. Loss 0.314, Accuracy 16.3): 100%|██████████| 2/2 [00:00<00:00,  5.17it/s]
# train_batch (Avg. Loss 0.294, Accuracy 14.8): 100%|██████████| 15/15 [00:03<00:00,  4.32it/s]
# test_batch (Avg. Loss 0.287, Accuracy 17.9): 100%|██████████| 2/2 [00:00<00:00,  5.21it/s]
# train_batch (Avg. Loss 0.302, Accuracy 14.4): 100%|██████████| 15/15 [00:03<00:00,  4.33it/s]
# test_batch (Avg. Loss 0.293, Accuracy 17.2): 100%|██████████| 2/2 [00:00<00:00,  5.56it/s]
# train_batch (Avg. Loss 0.315, Accuracy 13.7): 100%|██████████| 15/15 [00:03<00:00,  4.37it/s]
# test_batch (Avg. Loss 0.289, Accuracy 17.7): 100%|██████████| 2/2 [00:00<00:00,  5.15it/s]
# train_batch (Avg. Loss 0.298, Accuracy 14.4): 100%|██████████| 15/15 [00:03<00:00,  4.25it/s]
# test_batch (Avg. Loss 0.308, Accuracy 16.9): 100%|██████████| 2/2 [00:00<00:00,  5.13it/s]
# train_batch (Avg. Loss 0.286, Accuracy 15.1): 100%|██████████| 15/15 [00:03<00:00,  4.39it/s]
# test_batch (Avg. Loss 0.285, Accuracy 17.6): 100%|██████████| 2/2 [00:00<00:00,  5.40it/s]
# train_batch (Avg. Loss 0.307, Accuracy 14.4): 100%|██████████| 15/15 [00:03<00:00,  4.42it/s]
# test_batch (Avg. Loss 0.345, Accuracy 15.1): 100%|██████████| 2/2 [00:00<00:00,  5.28it/s]
# train_batch (Avg. Loss 0.273, Accuracy 15.5): 100%|██████████| 15/15 [00:03<00:00,  4.30it/s]
# test_batch (Avg. Loss 0.320, Accuracy 15.6): 100%|██████████| 2/2 [00:00<00:00,  5.29it/s]
# --- EPOCH 131/200 ---
# train_batch (Avg. Loss 0.293, Accuracy 14.7): 100%|██████████| 15/15 [00:03<00:00,  4.31it/s]
# test_batch (Avg. Loss 0.282, Accuracy 17.8): 100%|██████████| 2/2 [00:00<00:00,  6.57it/s]
# train_batch (Avg. Loss 0.297, Accuracy 14.6): 100%|██████████| 15/15 [00:02<00:00,  5.30it/s]
# test_batch (Avg. Loss 0.290, Accuracy 17.8): 100%|██████████| 2/2 [00:00<00:00,  6.55it/s]
# train_batch (Avg. Loss 0.279, Accuracy 15.3): 100%|██████████| 15/15 [00:03<00:00,  4.82it/s]
# test_batch (Avg. Loss 0.286, Accuracy 18.1): 100%|██████████| 2/2 [00:00<00:00,  6.63it/s]
# train_batch (Avg. Loss 0.293, Accuracy 14.8): 100%|██████████| 15/15 [00:02<00:00,  5.35it/s]
# test_batch (Avg. Loss 0.346, Accuracy 14.4): 100%|██████████| 2/2 [00:00<00:00,  6.81it/s]
# train_batch (Avg. Loss 0.282, Accuracy 15.2): 100%|██████████| 15/15 [00:03<00:00,  4.11it/s]
# test_batch (Avg. Loss 0.316, Accuracy 16.0): 100%|██████████| 2/2 [00:00<00:00,  3.90it/s]
# train_batch (Avg. Loss 0.295, Accuracy 14.8): 100%|██████████| 15/15 [00:03<00:00,  4.36it/s]
# test_batch (Avg. Loss 0.328, Accuracy 15.4): 100%|██████████| 2/2 [00:00<00:00,  5.05it/s]
# train_batch (Avg. Loss 0.302, Accuracy 14.6): 100%|██████████| 15/15 [00:03<00:00,  4.25it/s]
# test_batch (Avg. Loss 0.301, Accuracy 16.8): 100%|██████████| 2/2 [00:00<00:00,  5.28it/s]
# train_batch (Avg. Loss 0.301, Accuracy 14.4): 100%|██████████| 15/15 [00:04<00:00,  4.19it/s]
# test_batch (Avg. Loss 0.305, Accuracy 16.6): 100%|██████████| 2/2 [00:00<00:00,  5.24it/s]
# train_batch (Avg. Loss 0.298, Accuracy 14.7): 100%|██████████| 15/15 [00:03<00:00,  4.93it/s]
# test_batch (Avg. Loss 0.293, Accuracy 17.4): 100%|██████████| 2/2 [00:00<00:00,  6.77it/s]
# train_batch (Avg. Loss 0.296, Accuracy 14.7): 100%|██████████| 15/15 [00:02<00:00,  5.29it/s]
# test_batch (Avg. Loss 0.296, Accuracy 17.4): 100%|██████████| 2/2 [00:00<00:00,  6.80it/s]
# --- EPOCH 141/200 ---
# train_batch (Avg. Loss 0.310, Accuracy 14.2): 100%|██████████| 15/15 [00:03<00:00,  4.19it/s]
# test_batch (Avg. Loss 0.304, Accuracy 17.3): 100%|██████████| 2/2 [00:00<00:00,  5.13it/s]
# train_batch (Avg. Loss 0.284, Accuracy 15.1): 100%|██████████| 15/15 [00:03<00:00,  4.36it/s]
# test_batch (Avg. Loss 0.306, Accuracy 16.9): 100%|██████████| 2/2 [00:00<00:00,  5.30it/s]
# train_batch (Avg. Loss 0.291, Accuracy 14.9): 100%|██████████| 15/15 [00:03<00:00,  4.29it/s]
# test_batch (Avg. Loss 0.305, Accuracy 16.8): 100%|██████████| 2/2 [00:00<00:00,  5.22it/s]
# train_batch (Avg. Loss 0.292, Accuracy 14.9): 100%|██████████| 15/15 [00:03<00:00,  4.34it/s]
# test_batch (Avg. Loss 0.302, Accuracy 16.7): 100%|██████████| 2/2 [00:00<00:00,  5.14it/s]
# train_batch (Avg. Loss 0.281, Accuracy 15.4): 100%|██████████| 15/15 [00:03<00:00,  4.34it/s]
# test_batch (Avg. Loss 0.306, Accuracy 16.5): 100%|██████████| 2/2 [00:00<00:00,  5.33it/s]
# train_batch (Avg. Loss 0.282, Accuracy 15.3): 100%|██████████| 15/15 [00:03<00:00,  4.40it/s]
# test_batch (Avg. Loss 0.338, Accuracy 15.3): 100%|██████████| 2/2 [00:00<00:00,  5.34it/s]
# train_batch (Avg. Loss 0.292, Accuracy 15.0): 100%|██████████| 15/15 [00:03<00:00,  4.30it/s]
# test_batch (Avg. Loss 0.281, Accuracy 18.0): 100%|██████████| 2/2 [00:00<00:00,  5.28it/s]
# train_batch (Avg. Loss 0.301, Accuracy 14.5): 100%|██████████| 15/15 [00:03<00:00,  4.35it/s]
# test_batch (Avg. Loss 0.290, Accuracy 17.9): 100%|██████████| 2/2 [00:00<00:00,  5.22it/s]
# train_batch (Avg. Loss 0.282, Accuracy 15.3): 100%|██████████| 15/15 [00:03<00:00,  4.40it/s]
# test_batch (Avg. Loss 0.323, Accuracy 15.5): 100%|██████████| 2/2 [00:00<00:00,  5.46it/s]
# train_batch (Avg. Loss 0.299, Accuracy 14.7): 100%|██████████| 15/15 [00:03<00:00,  4.34it/s]
# test_batch (Avg. Loss 0.284, Accuracy 18.1): 100%|██████████| 2/2 [00:00<00:00,  5.24it/s]
# --- EPOCH 151/200 ---
# train_batch (Avg. Loss 0.294, Accuracy 14.7): 100%|██████████| 15/15 [00:03<00:00,  4.31it/s]
# test_batch (Avg. Loss 0.297, Accuracy 17.2): 100%|██████████| 2/2 [00:00<00:00,  5.33it/s]
# train_batch (Avg. Loss 0.306, Accuracy 14.2): 100%|██████████| 15/15 [00:03<00:00,  4.40it/s]
# test_batch (Avg. Loss 0.309, Accuracy 16.5): 100%|██████████| 2/2 [00:00<00:00,  5.22it/s]
# train_batch (Avg. Loss 0.302, Accuracy 14.4): 100%|██████████| 15/15 [00:03<00:00,  4.97it/s]
# test_batch (Avg. Loss 0.310, Accuracy 16.4): 100%|██████████| 2/2 [00:00<00:00,  6.41it/s]
# train_batch (Avg. Loss 0.301, Accuracy 14.4): 100%|██████████| 15/15 [00:02<00:00,  5.21it/s]
# test_batch (Avg. Loss 0.322, Accuracy 16.2): 100%|██████████| 2/2 [00:00<00:00,  6.57it/s]
# train_batch (Avg. Loss 0.300, Accuracy 14.5): 100%|██████████| 15/15 [00:02<00:00,  5.25it/s]
# test_batch (Avg. Loss 0.303, Accuracy 17.1): 100%|██████████| 2/2 [00:00<00:00,  6.58it/s]
# train_batch (Avg. Loss 0.292, Accuracy 15.0): 100%|██████████| 15/15 [00:02<00:00,  5.18it/s]
# test_batch (Avg. Loss 0.278, Accuracy 18.3): 100%|██████████| 2/2 [00:00<00:00,  6.59it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 156
# train_batch (Avg. Loss 0.293, Accuracy 15.0): 100%|██████████| 15/15 [00:02<00:00,  5.31it/s]
# test_batch (Avg. Loss 0.340, Accuracy 14.8): 100%|██████████| 2/2 [00:00<00:00,  6.68it/s]
# train_batch (Avg. Loss 0.292, Accuracy 14.7): 100%|██████████| 15/15 [00:02<00:00,  5.20it/s]
# test_batch (Avg. Loss 0.323, Accuracy 15.8): 100%|██████████| 2/2 [00:00<00:00,  6.56it/s]
# train_batch (Avg. Loss 0.289, Accuracy 15.0): 100%|██████████| 15/15 [00:02<00:00,  5.28it/s]
# test_batch (Avg. Loss 0.281, Accuracy 18.2): 100%|██████████| 2/2 [00:00<00:00,  6.76it/s]
# train_batch (Avg. Loss 0.309, Accuracy 13.9): 100%|██████████| 15/15 [00:02<00:00,  5.31it/s]
# test_batch (Avg. Loss 0.298, Accuracy 16.9): 100%|██████████| 2/2 [00:00<00:00,  6.79it/s]
# --- EPOCH 161/200 ---
# train_batch (Avg. Loss 0.296, Accuracy 14.6): 100%|██████████| 15/15 [00:02<00:00,  5.39it/s]
# test_batch (Avg. Loss 0.285, Accuracy 17.9): 100%|██████████| 2/2 [00:00<00:00,  6.58it/s]
# train_batch (Avg. Loss 0.298, Accuracy 14.7): 100%|██████████| 15/15 [00:02<00:00,  5.28it/s]
# test_batch (Avg. Loss 0.310, Accuracy 16.5): 100%|██████████| 2/2 [00:00<00:00,  6.70it/s]
# train_batch (Avg. Loss 0.289, Accuracy 15.0): 100%|██████████| 15/15 [00:02<00:00,  5.31it/s]
# test_batch (Avg. Loss 0.362, Accuracy 14.9): 100%|██████████| 2/2 [00:00<00:00,  6.83it/s]
# train_batch (Avg. Loss 0.308, Accuracy 14.2): 100%|██████████| 15/15 [00:02<00:00,  5.30it/s]
# test_batch (Avg. Loss 0.302, Accuracy 17.2): 100%|██████████| 2/2 [00:00<00:00,  6.33it/s]
# train_batch (Avg. Loss 0.285, Accuracy 15.1): 100%|██████████| 15/15 [00:02<00:00,  5.31it/s]
# test_batch (Avg. Loss 0.277, Accuracy 18.4): 100%|██████████| 2/2 [00:00<00:00,  6.67it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 165
# train_batch (Avg. Loss 0.285, Accuracy 15.1): 100%|██████████| 15/15 [00:02<00:00,  5.34it/s]
# test_batch (Avg. Loss 0.271, Accuracy 18.7): 100%|██████████| 2/2 [00:00<00:00,  6.84it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 166
# train_batch (Avg. Loss 0.296, Accuracy 14.7): 100%|██████████| 15/15 [00:02<00:00,  5.29it/s]
# test_batch (Avg. Loss 0.303, Accuracy 16.8): 100%|██████████| 2/2 [00:00<00:00,  6.78it/s]
# train_batch (Avg. Loss 0.302, Accuracy 14.5): 100%|██████████| 15/15 [00:02<00:00,  5.28it/s]
# test_batch (Avg. Loss 0.304, Accuracy 16.5): 100%|██████████| 2/2 [00:00<00:00,  6.72it/s]
# train_batch (Avg. Loss 0.293, Accuracy 14.6): 100%|██████████| 15/15 [00:02<00:00,  5.34it/s]
# test_batch (Avg. Loss 0.315, Accuracy 16.6): 100%|██████████| 2/2 [00:00<00:00,  6.67it/s]
# train_batch (Avg. Loss 0.312, Accuracy 14.2): 100%|██████████| 15/15 [00:02<00:00,  5.25it/s]
# test_batch (Avg. Loss 0.306, Accuracy 16.7): 100%|██████████| 2/2 [00:00<00:00,  6.71it/s]
# --- EPOCH 171/200 ---
# train_batch (Avg. Loss 0.303, Accuracy 14.3): 100%|██████████| 15/15 [00:02<00:00,  5.34it/s]
# test_batch (Avg. Loss 0.306, Accuracy 16.8): 100%|██████████| 2/2 [00:00<00:00,  6.73it/s]
# train_batch (Avg. Loss 0.306, Accuracy 14.3): 100%|██████████| 15/15 [00:02<00:00,  5.18it/s]
# test_batch (Avg. Loss 0.294, Accuracy 17.2): 100%|██████████| 2/2 [00:00<00:00,  6.82it/s]
# train_batch (Avg. Loss 0.290, Accuracy 14.9): 100%|██████████| 15/15 [00:03<00:00,  4.27it/s]
# test_batch (Avg. Loss 0.297, Accuracy 17.0): 100%|██████████| 2/2 [00:00<00:00,  5.23it/s]
# train_batch (Avg. Loss 0.289, Accuracy 14.9): 100%|██████████| 15/15 [00:03<00:00,  4.41it/s]
# test_batch (Avg. Loss 0.304, Accuracy 16.7): 100%|██████████| 2/2 [00:00<00:00,  5.20it/s]
# train_batch (Avg. Loss 0.290, Accuracy 14.9): 100%|██████████| 15/15 [00:03<00:00,  4.31it/s]
# test_batch (Avg. Loss 0.273, Accuracy 18.7): 100%|██████████| 2/2 [00:00<00:00,  5.21it/s]
# train_batch (Avg. Loss 0.286, Accuracy 15.0): 100%|██████████| 15/15 [00:03<00:00,  4.28it/s]
# test_batch (Avg. Loss 0.307, Accuracy 16.3): 100%|██████████| 2/2 [00:00<00:00,  5.25it/s]
# train_batch (Avg. Loss 0.314, Accuracy 14.0): 100%|██████████| 15/15 [00:03<00:00,  4.39it/s]
# test_batch (Avg. Loss 0.303, Accuracy 17.1): 100%|██████████| 2/2 [00:00<00:00,  5.30it/s]
# train_batch (Avg. Loss 0.302, Accuracy 14.5): 100%|██████████| 15/15 [00:03<00:00,  4.17it/s]
# test_batch (Avg. Loss 0.295, Accuracy 17.5): 100%|██████████| 2/2 [00:00<00:00,  6.61it/s]
# train_batch (Avg. Loss 0.311, Accuracy 14.2): 100%|██████████| 15/15 [00:03<00:00,  4.81it/s]
# test_batch (Avg. Loss 0.286, Accuracy 17.8): 100%|██████████| 2/2 [00:00<00:00,  6.70it/s]
# train_batch (Avg. Loss 0.303, Accuracy 14.3): 100%|██████████| 15/15 [00:02<00:00,  5.28it/s]
# test_batch (Avg. Loss 0.315, Accuracy 16.3): 100%|██████████| 2/2 [00:00<00:00,  6.62it/s]
# --- EPOCH 181/200 ---
# train_batch (Avg. Loss 0.302, Accuracy 14.4): 100%|██████████| 15/15 [00:02<00:00,  5.26it/s]
# test_batch (Avg. Loss 0.282, Accuracy 18.0): 100%|██████████| 2/2 [00:00<00:00,  6.59it/s]
# train_batch (Avg. Loss 0.293, Accuracy 15.0): 100%|██████████| 15/15 [00:02<00:00,  5.32it/s]
# test_batch (Avg. Loss 0.339, Accuracy 15.7): 100%|██████████| 2/2 [00:00<00:00,  6.84it/s]
# train_batch (Avg. Loss 0.279, Accuracy 15.3): 100%|██████████| 15/15 [00:02<00:00,  5.30it/s]
# test_batch (Avg. Loss 0.307, Accuracy 16.5): 100%|██████████| 2/2 [00:00<00:00,  6.63it/s]
# train_batch (Avg. Loss 0.280, Accuracy 15.4): 100%|██████████| 15/15 [00:02<00:00,  5.32it/s]
# test_batch (Avg. Loss 0.289, Accuracy 17.6): 100%|██████████| 2/2 [00:00<00:00,  6.77it/s]
# train_batch (Avg. Loss 0.302, Accuracy 14.6): 100%|██████████| 15/15 [00:02<00:00,  5.24it/s]
# test_batch (Avg. Loss 0.287, Accuracy 18.5): 100%|██████████| 2/2 [00:00<00:00,  6.45it/s]
# train_batch (Avg. Loss 0.297, Accuracy 14.9): 100%|██████████| 15/15 [00:02<00:00,  5.30it/s]
# test_batch (Avg. Loss 0.296, Accuracy 17.2): 100%|██████████| 2/2 [00:00<00:00,  6.66it/s]
# train_batch (Avg. Loss 0.286, Accuracy 15.2): 100%|██████████| 15/15 [00:02<00:00,  5.29it/s]
# test_batch (Avg. Loss 0.271, Accuracy 19.0): 100%|██████████| 2/2 [00:00<00:00,  6.73it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 187
# train_batch (Avg. Loss 0.292, Accuracy 14.7): 100%|██████████| 15/15 [00:02<00:00,  5.32it/s]
# test_batch (Avg. Loss 0.286, Accuracy 17.7): 100%|██████████| 2/2 [00:00<00:00,  6.27it/s]
# train_batch (Avg. Loss 0.299, Accuracy 14.5): 100%|██████████| 15/15 [00:02<00:00,  5.30it/s]
# test_batch (Avg. Loss 0.293, Accuracy 17.3): 100%|██████████| 2/2 [00:00<00:00,  6.47it/s]
# train_batch (Avg. Loss 0.307, Accuracy 14.3): 100%|██████████| 15/15 [00:02<00:00,  4.96it/s]
# test_batch (Avg. Loss 0.294, Accuracy 17.3): 100%|██████████| 2/2 [00:00<00:00,  5.45it/s]
# --- EPOCH 191/200 ---
# train_batch (Avg. Loss 0.275, Accuracy 15.6): 100%|██████████| 15/15 [00:03<00:00,  4.29it/s]
# test_batch (Avg. Loss 0.300, Accuracy 17.1): 100%|██████████| 2/2 [00:00<00:00,  5.28it/s]
# train_batch (Avg. Loss 0.288, Accuracy 15.2): 100%|██████████| 15/15 [00:03<00:00,  4.01it/s]
# test_batch (Avg. Loss 0.296, Accuracy 17.1): 100%|██████████| 2/2 [00:00<00:00,  4.81it/s]
# train_batch (Avg. Loss 0.296, Accuracy 14.5): 100%|██████████| 15/15 [00:03<00:00,  4.39it/s]
# test_batch (Avg. Loss 0.301, Accuracy 17.6): 100%|██████████| 2/2 [00:00<00:00,  5.16it/s]
# train_batch (Avg. Loss 0.298, Accuracy 14.6): 100%|██████████| 15/15 [00:03<00:00,  4.33it/s]
# test_batch (Avg. Loss 0.303, Accuracy 16.8): 100%|██████████| 2/2 [00:00<00:00,  5.47it/s]
# train_batch (Avg. Loss 0.300, Accuracy 14.5): 100%|██████████| 15/15 [00:03<00:00,  3.22it/s]
# test_batch (Avg. Loss 0.285, Accuracy 17.9): 100%|██████████| 2/2 [00:00<00:00,  5.08it/s]
# train_batch (Avg. Loss 0.288, Accuracy 14.9): 100%|██████████| 15/15 [00:03<00:00,  4.31it/s]
# test_batch (Avg. Loss 0.440, Accuracy 11.1): 100%|██████████| 2/2 [00:00<00:00,  5.31it/s]
# train_batch (Avg. Loss 0.278, Accuracy 15.5): 100%|██████████| 15/15 [00:03<00:00,  4.20it/s]
# test_batch (Avg. Loss 0.321, Accuracy 16.2): 100%|██████████| 2/2 [00:00<00:00,  5.18it/s]
# train_batch (Avg. Loss 0.302, Accuracy 14.5): 100%|██████████| 15/15 [00:03<00:00,  4.39it/s]
# test_batch (Avg. Loss 0.290, Accuracy 17.5): 100%|██████████| 2/2 [00:00<00:00,  4.70it/s]
# train_batch (Avg. Loss 0.308, Accuracy 14.1): 100%|██████████| 15/15 [00:03<00:00,  4.46it/s]
# test_batch (Avg. Loss 0.308, Accuracy 16.7): 100%|██████████| 2/2 [00:00<00:00,  6.54it/s]
# --- EPOCH 200/200 ---
# train_batch (Avg. Loss 0.307, Accuracy 14.3): 100%|██████████| 15/15 [00:03<00:00,  4.30it/s]
# test_batch (Avg. Loss 0.277, Accuracy 18.5): 100%|██████████| 2/2 [00:00<00:00,  5.35it/s]
# *** Images Generated from best model:

# %% [markdown]
# ## Questions
# <a id=part2_7></a>

# %% [markdown]
# **TODO** Answer the following questions. Write your answers in the appropriate variables in the module `hw3/answers.py`.

# %%
from cs236605.answers import display_answer
import hw3.answers

# %% [markdown]
# ### Question 1
#
# What does the $\sigma^2$ hyperparameter (`x_sigma2` in the code) do? Explain the effect of low and high values.

# %%
display_answer(hw3.answers.part2_q1)
# Out:
# **Your answer:**
#
#
# $\sigma$ acts as a regularisation strength. since our loss is composed of a Data-loss and a a distrobution-loss (KLdiv), the parameter $\sigma$ defines the strength of the Data-loss. when sigma is high, the weight of the Data-loss is smaller so the regularisation is stronger. and when sigma is low the weight of the Data-loss is much bigger so the model try to fit more to the data itself.
